# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow_felzenszwalb_edt
import scipy as sp
import scipy.misc
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
a=scipy.misc.face(gray=True).astype(np.float32)

# %%
b=tensorflow_felzenszwalb_edt.edt1d(a*100,axis=0)
plt.imshow(b)

# %%
b=tensorflow_felzenszwalb_edt.edt1d(a*100,axis=1)
plt.imshow(b)
